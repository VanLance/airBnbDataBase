# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('AB_NYC_2019.csv')
air_bnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# How many neighborhood groups are available and which shows up the most?
air_bnb.groupby('neighbourhood_group').count()
# 5 groups and Manhattan shows up most
# Out:
#                         id   name  host_id  host_name  neighbourhood  \
# neighbourhood_group
# Bronx                 1091   1090     1091       1090           1091
# Brooklyn             20104  20098    20104      20095          20104
# Manhattan            21661  21652    21661      21652          21661
# Queens                5666   5666     5666       5664           5666
# Staten Island          373    373      373        373            373
#
#                      latitude  longitude  room_type  price  minimum_nights  \
# neighbourhood_group
# Bronx                    1091       1091       1091   1091            1091
# Brooklyn                20104      20104      20104  20104           20104
# Manhattan               21661      21661      21661  21661           21661
# Queens                   5666       5666       5666   5666            5666
# Staten Island             373        373        373    373             373
#
# ...

# %%
# Are private rooms the most popular in manhattan?
air_bnb.groupby(['neighbourhood_group', 'room_type']).count()
# Entire Homes are more popular in Manhatten
# Bronx 60%, Brooklyn 50%, Man 36%... and more popular in other areas
# Out:
#                                         id   name  host_id  host_name  \
# neighbourhood_group room_type
# Bronx               Entire home/apt    379    379      379        378
#                     Private room       652    652      652        652
#                     Shared room         60     59       60         60
# Brooklyn            Entire home/apt   9559   9558     9559       9554
#                     Private room     10132  10127    10132      10128
#                     Shared room        413    413      413        413
# Manhattan           Entire home/apt  13199  13193    13199      13196
#                     Private room      7982   7979     7982       7976
#                     Shared room        480    480      480        480
# Queens              Entire home/apt   2096   2096     2096       2096
#                     Private room      3372   3372     3372       3370
#                     Shared room        198    198      198        198
# ...

# %%
# Which hosts are the busiest and based on their reviews?
#air_bnb.groupby('host_id').sort_values('reviews_per_month', ascending= False)
hosts = air_bnb.groupby(['host_id', 'host_name']).sum().sort_values('reviews_per_month', ascending=False)
hosts.head(10)
# Sonder number 1 with 1281 per month
# Out:
#                                                    id     latitude  \
# host_id   host_name
# 219517861 Sonder (NYC)                    10885561678  13316.25823
# 244361589 Row NYC                           294108503    366.82627
# 232251881 Lakshmee                          254974885    325.33942
# 26432133  Danielle                           74542317    203.81845
# 137274917 David                             345517389    489.12293
# 224414117 Gabriel                           921229890   1222.67553
# 156948703 Asad                              135792224    244.61926
# 344035    Brooklyn&   Breakfast    -Len-    155403744    528.82140
# 156684502 Nalicia                            66477294    121.98566
# 37312959  Maya                               51232186    203.85153
#
#                                             longitude  price  minimum_nights  \
# host_id   host_name
# 219517861 Sonder (NYC)                   -24198.18856  82795            4353
# ...

# %%
#Which neighorhood group has the highest average price?
air_bnb.groupby('neighbourhood_group').mean().sort_values('price', ascending=False)
# Out:
#                                id       host_id   latitude  longitude  \
# neighbourhood_group
# Manhattan            1.877494e+07  6.783062e+07  40.765062 -73.974607
# Brooklyn             1.825685e+07  5.671526e+07  40.685036 -73.951190
# Staten Island        2.159747e+07  9.853360e+07  40.610225 -74.105805
# Queens               2.175500e+07  9.615680e+07  40.731531 -73.872775
# Bronx                2.273492e+07  1.056099e+08  40.848305 -73.884552
#
#                           price  minimum_nights  number_of_reviews  \
# neighbourhood_group
# Manhattan            196.875814        8.579151          20.985596
# Brooklyn             124.383207        6.056556          24.202845
# Staten Island        114.812332        4.831099          30.941019
# Queens                99.517649        5.181433          27.700318
# Bronx                 87.496792        4.560953          26.004583
#
#                      reviews_per_month  calculated_host_listings_count  \
# neighbourhood_group
# ...

# %%
# Which neighbor hood group has the highest total price?
air_bnb.groupby('neighbourhood_group').sum().sort_values('price', ascending=False)
# Out:
#                                id        host_id      latitude     longitude  \
# neighbourhood_group
# Manhattan            406683958152  1469279004836  883012.01680 -1.602364e+06
# Brooklyn             367035792483  1140203577483  817931.96821 -1.486715e+06
# Queens               123263814259   544824426112  230784.85597 -4.185631e+05
# Bronx                 24803796188   115220380205   44565.50071 -8.060805e+04
# Staten Island          8055857451    36753031930   15147.61383 -2.764147e+04
#
#                        price  minimum_nights  number_of_reviews  \
# neighbourhood_group
# Manhattan            4264527          185833             454569
# Brooklyn             2500600          121761             486574
# Queens                563867           29358             156950
# Bronx                  95459            4976              28371
# Staten Island          42825            1802              11541
#
#                      reviews_per_month  calculated_host_listings_count  \
# ...

# %%
#Which top 5 hosts have the highest total price?
hosts = air_bnb.groupby(['host_id', 'host_name', 'price']).sum().sort_values('reviews_per_month', ascending=False)
hosts.head(10)
# Out:
#                                        id   latitude   longitude  \
# host_id   host_name      price
# 244361589 Row NYC        100    130714889  163.03429  -295.95363
# 26432133  Danielle       48      51672873  122.29082  -221.61333
# 16677326  Alex And Zeena 85     170606621  488.98427  -887.95071
# 219517861 Sonder (NYC)   229    557247319  692.01706 -1258.18179
# 156684502 Nalicia        50      44926992   81.32456  -147.54050
# 187822288 Zahir          55     133542938  163.08168  -295.49055
# 244559229 Stewart Hotel  100    294087418  366.74061  -665.92596
# 37312959  Maya           45      28930153  122.31138  -221.62811
# 19536596  Andrew         48     134084107  203.38413  -369.53724
# 137274917 David          110    172258458  244.56226  -443.94382
#
#                                 minimum_nights  number_of_reviews  \
# host_id   host_name      price
# 244361589 Row NYC        100                 4                201
# ...

# %%
# Who currently has no (zero) availability with a review count of 100 or more?

air_bnb[(air_bnb['number_of_reviews']>=100)&(air_bnb['availability_365']==0)].groupby('host_name').sum()
# Out:
#                      id   host_id  latitude  longitude  price  minimum_nights  \
# host_name
# AJ And Freddy    728409   3778274  40.70061  -73.95520     65               2
# Abraham         9544914  22423049  40.67157  -73.94117     36               2
# Adrienne         258740   1360043  40.81872  -73.94567     58               1
# Airamis        15307603  92195100  40.85236  -73.86632     35               1
# Albert         24267706  21074914  40.68234  -73.91318     49               1
# ...                 ...       ...       ...        ...    ...             ...
# Véronique       2339096  11947308  40.71590  -73.99059     70               1
# Wanda            166172    792159  40.70283  -73.92131     60               3
# William         5848141  28171102  81.47120 -147.89233    225               6
# Yuval          19069305  10402380  40.67245  -73.96358     50               1
# 正川              6269646  25915648  40.75532  -73.82060     41               2
#
# ...

# %%
# What host has the highest total of prices and where are they located?
total_rice = air_bnb.groupby('host_name').sum().sort_values('price', ascending = False)
total_rice.head(3)

# %%
# When did Danielle from Queens last receive a review?
air_bnb[air_bnb['host_name'] == "Danielle"].sort_values('last_review', ascending =False)
# Out:
#              id                                               name   host_id  \
# 22469  18173787  Cute Tiny Room Family Home by LGA NO CLEANING FEE  26432133
# 21517  17222454   Sun Room Family Home LGA Airport NO CLEANING FEE  26432133
# 20403  16276632  Cozy Room Family Home LGA Airport NO CLEANING FEE  26432133
# 5717    4163781                  Sun Soaked & Cozy PR Williamsburg   1401835
# 29546  22686497  Backyard BK! Live like a NY’er in modern, new ...  24124835
# ...         ...                                                ...       ...
# 16349  13151075                    ASTORIA APARTMENT OUTDOOR SPACE  18051286
# 34760  27552582                Studio in the Heart of East Village  30680112
# 37221  29570887  LARGE ROOM ‘N CLINTON HILL, Brooklyn, w / LAUN...  24124835
# 43825  33901005     Sunny, Spacious, Cozy, Charming Brooklyn Abode    192752
# 48533  36310353  Staten Island Resort minutes from ferry! Amazi...  28586423
#
# ...

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
air_bnb.groupby('host_name').count().sort_values('calculated_host_listings_count', ascending= False).head()
# Out:
#                id  name  host_id  neighbourhood_group  neighbourhood  \
# host_name
# Michael       417   417      417                  417            417
# David         403   403      403                  403            403
# Sonder (NYC)  327   327      327                  327            327
# John          294   294      294                  294            294
# Alex          279   279      279                  279            279
#
#               latitude  longitude  room_type  price  minimum_nights  \
# host_name
# Michael            417        417        417    417             417
# David              403        403        403    403             403
# Sonder (NYC)       327        327        327    327             327
# John               294        294        294    294             294
# Alex               279        279        279    279             279
#
#               number_of_reviews  last_review  reviews_per_month  \
# host_name
# ...

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
air_bnb[air_bnb['availability_365'] == 365]
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 36        11452                        Clean and Quiet in Brooklyn       7355
# 38        11943                          Country space in the city      45445
# 97        21644                          Upper Manhattan, New York      82685
# ...         ...                                                ...        ...
# 48744  36415840         A BEAUTIFUL SPACE IN HEART OF WILLIAMSBURG  223715460
# 48844  36453952    West Village Studio on quiet cobblestone street  115491896
# 48868  36473253                       Heaven for you(only for guy)  261338177
# 48880  36481315  The Raccoon Artist Studio in Williamsburg New ...  208514239
# 48887  36483152    Garden Jewel Apartment in Williamsburg New York  208514239
#
# ...

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
air_bnb.groupby('room_type').sum().sort_values('number_of_reviews', ascending= False)
# Out:
#                            id        host_id      latitude     longitude  \
# room_type
# Entire home/apt  468495600287  1569156532318  1.034874e+06 -1.879267e+06
# Private room     434663231749  1618079882718  9.093203e+05 -1.650850e+06
# Shared room       26684386497   119044005530  4.724740e+04 -8.577428e+04
#
#                    price  minimum_nights  number_of_reviews  \
# room_type
# Entire home/apt  5381480          216152             580403
# Private room     2004450          120067             538346
# Shared room        81348            7511              19256
#
#                  reviews_per_month  calculated_host_listings_count  \
# room_type
# Entire home/apt           26565.34                          271834
# Private room              25529.62                           72062
# Shared room                1245.08                            5409
#
#                  availability_365
# room_type
# Entire home/apt           2843783
# Private room              2482739
# ...

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
